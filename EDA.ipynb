# %%
import pandas as pd
import json

# %%
with open("./police-department-calls-for-service.json") as fp:
    data = json.load(fp)
    
data
# Out:
# [{'crime_id': '183653763',
#   'original_crime_type_name': 'Traffic Stop',
#   'report_date': '2018-12-31T00:00:00.000',
#   'call_date': '2018-12-31T00:00:00.000',
#   'offense_date': '2018-12-31T00:00:00.000',
#   'call_time': '23:57',
#   'call_date_time': '2018-12-31T23:57:00.000',
#   'disposition': 'ADM',
#   'address': 'Geary Bl/divisadero St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'agency_id': '1',
#   'address_type': 'Intersection',
#   'common_location': ''},
#  {'crime_id': '183653756',
#   'original_crime_type_name': 'Traf Violation Cite',
#   'report_date': '2018-12-31T00:00:00.000',
#   'call_date': '2018-12-31T00:00:00.000',
#   'offense_date': '2018-12-31T00:00:00.000',
#   'call_time': '23:54',
#   'call_date_time': '2018-12-31T23:54:00.000',
#   'disposition': 'CIT',
#   'address': '100 Blk Howard St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'agency_id': '1',
#   'address_type': 'Geo-Override',
#   'common_location': ''},
# ...

# %%
df  = pd.DataFrame(data)
df.loc[:, ["disposition", "original_crime_type_name"]].head(50)
# Out:
#      disposition original_crime_type_name
# 0            ADM             Traffic Stop
# 1            CIT      Traf Violation Cite
# 2            HAN             Passing Call
# 3            PAS            Audible Alarm
# 4            CIT             Traffic Stop
# 5             ND             Passing Call
# 6            CIT             Traffic Stop
# 7            HAN             Traffic Stop
# 8   Not recorded             Passing Call
# 9            GOA          Fight No Weapon
# 10           HAN             Traffic Stop
# 11           HAN             Passing Call
# 12           HAN             Passing Call
# 13           CIT             Traffic Stop
# 14           REP                      Att
# 15           REP       Auto Boost / Strip
# 16           HAN             Passing Call
# 17           ADV             Traffic Stop
# 18           HAN             Passing Call
# 19           ADV       Suspicious Vehicle
# 20           PAS            Audible Alarm
# ...

# %%
df.dtypes
# Out:
# address                     object
# address_type                object
# agency_id                   object
# call_date                   object
# call_date_time              object
# call_time                   object
# city                        object
# common_location             object
# crime_id                    object
# disposition                 object
# offense_date                object
# original_crime_type_name    object
# report_date                 object
# state                       object
# dtype: object

# %%
df["call_date_time"]
# Out:
# 0         2018-12-31T23:57:00.000
# 1         2018-12-31T23:54:00.000
# 2         2018-12-31T23:49:00.000
# 3         2018-12-31T23:47:00.000
# 4         2018-12-31T23:46:00.000
# 5         2018-12-31T23:38:00.000
# 6         2018-12-31T23:38:00.000
# 7         2018-12-31T23:36:00.000
# 8         2018-12-31T23:34:00.000
# 9         2018-12-31T23:33:00.000
# 10        2018-12-31T23:33:00.000
# 11        2018-12-31T23:33:00.000
# 12        2018-12-31T23:33:00.000
# 13        2018-12-31T23:30:00.000
# 14        2018-12-31T23:30:00.000
# 15        2018-12-31T23:29:00.000
# 16        2018-12-31T23:29:00.000
# 17        2018-12-31T23:28:00.000
# 18        2018-12-31T23:25:00.000
# 19        2018-12-31T23:24:00.000
# 20        2018-12-31T23:24:00.000
# 21        2018-12-31T23:21:00.000
# 22        2018-12-31T23:21:00.000
# 23        2018-12-31T23:21:00.000
# 24        2018-12-31T23:20:00.000
# 25        2018-12-31T23:19:00.000
# 26        2018-12-31T23:19:00.000
# ...
